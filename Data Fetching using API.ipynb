# %%
import pandas as pd
import requests

# %%
url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
"x-rapidapi-key": "ba5a5db7ddmsh03a710940c9d39fp1d4135jsn44f21f2a320a",
"x-rapidapi-host": "imdb-top-100-movies.p.rapidapi.com"
}

# %%
response=requests.get(url,headers=headers)

# %%
Data=pd.DataFrame(response.json())

# %%
Final_data=Data[['rank','title','description','genre','rating','year']]
Final_data
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96            Reservoir Dogs
# 96    97                     Ikiru
# 97    98        Lawrence of Arabia
# 98    99              Citizen Kane
# 99   100                         M
#
#                                           description  \
# 0   Two imprisoned men bond over a number of years...
# 1   The aging patriarch of an organized crime dyna...
# 2   When the menace known as the Joker wreaks havo...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# ..                                                ...
# 95  When a simple jewelry heist goes horribly wron...
# 96  A bureaucrat tries to find meaning in his life...
# ...

# %%
df=pd.DataFrame()

# %%
for i in range(1,200):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity']]
    df=pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#           id                       title  \
# 0        640         Catch Me If You Can
# 1     916224                      Suzume
# 2      28422               Love Exposure
# 3        862                   Toy Story
# 4       2517                Nobody Knows
# ...      ...                         ...
# 8675  440161        The Sisters Brothers
# 8676    8974       The War of the Worlds
# 8677    1494  Curse of the Golden Flower
# 8678  606566              The Best Years
# 8679  299537              Captain Marvel
#
#                                                overview release_date  \
# 0     A true story about Frank Abagnale Jr. who, bef...   2002-12-16
# 1     Suzume, 17, lost her mother as a little girl. ...   2022-11-11
# 2     The story of a teenage boy named Yu, who falls...   2009-01-31
# 3     Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 4     In a small Tokyo apartment, twelve-year-old Ak...   2004-08-07
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8675     True
# 8676     True
# 8677     True
# 8678     True
# 8679     True
# Length: 8680, dtype: bool

# %%
df.drop_duplicates()
# Out:
#           id                        title  \
# 0        640          Catch Me If You Can
# 1     916224                       Suzume
# 2      28422                Love Exposure
# 3        862                    Toy Story
# 4       2517                 Nobody Knows
# ...      ...                          ...
# 4695    2976                    Hairspray
# 4696    2161             Fantastic Voyage
# 4697    1788                    Footloose
# 4698  967847  Ghostbusters: Frozen Empire
# 4699  882598                        Smile
#
#                                                overview release_date  \
# 0     A true story about Frank Abagnale Jr. who, bef...   2002-12-16
# 1     Suzume, 17, lost her mother as a little girl. ...   2022-11-11
# 2     The story of a teenage boy named Yu, who falls...   2009-01-31
# 3     Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 4     In a small Tokyo apartment, twelve-year-old Ak...   2004-08-07
# ...

# %%
df.to_csv('movies_csv')
